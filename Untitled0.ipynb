# %% [markdown]
# <a href="https://colab.research.google.com/github/kudupudimeghana/problems-practicing/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Interview Programs
# Reverse a string with slicing

# %%
s = input("enter a word")
print(s[::-1])
# Out:
# enter a wordhello
# olleh

# %%
#reverse a string without slicing
s = input("enter a word")
rev = ""
for char in s:
  rev = char + rev
print(rev)
# Out:
# enter a wordhello
# olleh
